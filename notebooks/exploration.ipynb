# %% [markdown]
# # Exploración inicial
#
# Este notebook carga el dataset de ejemplo en `data/examples/example_matches.csv` y realiza una inspección rápida para validar el esquema de datos.

# %%
import pandas as pd
df = pd.read_csv('data/examples/example_matches.csv')
df.head()
